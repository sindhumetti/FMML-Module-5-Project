# %% [markdown]
# <a href="https://colab.research.google.com/github/sindhumetti/FMML-Module-5-Project/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 12:28:28--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   174MB/s    in 0.4s
#
# 2024-03-31 12:28:28 (174 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 31439  1803.04022v1  Deep dictionary learning seeks multiple dictio...    cs
# 11258  1506.06100v1  We introduce the Variational Holder (VH) bound...  stat
# 7209   1711.01297v1  We interpret HyperNetworks within the framewor...  stat
# 2931   1708.04670v1  Previous research on automatic pain estimation...    cs
# 20826  1703.04741v3  Both the ethics of autonomous systems and the ...    cs
# ...             ...                                                ...   ...
# 22545  1611.02440v2  Game theory finds nowadays a broad range of ap...  stat
# 22203  1507.05870v2  In this paper, we consider a statistical probl...  stat
# 21997   1310.3745v2  Mixed linear regression involves the recovery ...  stat
# 22357  1603.04381v2  We consider the problem of maximizing an unkno...  stat
# 21755   1109.2553v2  When response variables are nominal and popula...  stat
#
#                                                    title  year  \
# 31439  Deep Dictionary Learning: A PARametric NETwork...  2018
# 11258  Approximate Inference with the Variational Hol...  2015
# 7209      Implicit Weight Uncertainty in Neural Networks  2017
# 2931   DeepFaceLIFT: Interpretable Personalized Model...  2017
# 20826                   Towards Moral Autonomous Systems  2017
# ...                                                  ...   ...
# 22545  A Bayesian optimization approach to find Nash ...  2016
# 22203  A statistical perspective of sampling scores f...  2015
# 21997  Alternating Minimization for Mixed Linear Regr...  2013
# 22357          A ranking approach to global optimization  2016
# 21755              Nominal Association Vector and Matrix  2011
#
#                                                 keywords
# 31439  [dictionary, dictionaries, different, compleme...
# 11258  [introduce, variational, alternative, variatio...
# 7209   [interpret, hypernetworks, framework, variatio...
# 2931   [automatic, estimation, expressions, primarily...
# 20826  [autonomous, technical, implementation, attent...
# ...                                                  ...
# 22545  [applications, engineering, derivative, expens...
# 22203  [statistical, approximating, importance, distr...
# 21997  [regression, unlabeled, measurements, empirica...
# 22357  [maximizing, observations, optimization, essen...
# 21755  [variables, populations, classified, polytomie...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 31439    [dictionary, dictionaries, different, compleme...
# 11258    [introduce, variational, alternative, variatio...
# 7209     [interpret, hypernetworks, framework, variatio...
# 2931     [automatic, estimation, expressions, primarily...
# 20826    [autonomous, technical, implementation, attent...
#                                ...
# 31342    [challenge, segmentation, competition, specifi...
# 26426    [contributes, incremental, classification, sta...
# 11575    [commentary, numerical, optimization, algorith...
# 28980    [applications, discovered, including, performi...
# 18561    [identifying, eliminating, mislabeled, instanc...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8819 words.
# Out of those 4593 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b8373f48-e913-4ae9-83ed-3bbcc6574f26" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8373f48-e913-4ae9-83ed-3bbcc6574f26")) {                    Plotly.newPlot(                        "b8373f48-e913-4ae9-83ed-3bbcc6574f26",                        [{"x":["hierarchy","complementary","remarkably","objectives","consequently","benchmark","furthermore","perturbation","dictionaries","reconstruction","classification","extracted","adversarial","different","regularize","parametric","parameters","increases","information","validation","hierarchical","characteristics","performance","dictionary","algorithm","objective","synthesis","optimization","algorithms","multivariate","intractable","inference","approximation","minimization","numerical","alternative","typically","integrating","integration","maximization","distribution","approximate","truncated","introduce","experiments","variational","literature","uncertainties","distributions","providing","interpret","hypernetworks","predictive","likelihood","comparable","uncertainty","framework","interpretable","estimation","primarily","automatic","outperforms","significantly","automatically","subjective","personalize","discovers","estimating","individuals","expressions","dependent","expression","personalized","traditional","regression","interpretation","measurement","correlation","considered","estimates","additionally","confidence","technical","overlooked","engineering","transparency","implications","legislation","philosophy","implementation","accountability","approaches","autonomous","intersection","requirements","addresses","deployment","possibility","deliberately","challenges","specification","precisely","philosophers","conceptual","unethical","attention","verification","regarding","particularly","engineers","problematic","distributed","mapreduce","evaluation","favorably","dynamically","subsample","appropriate","ensembles","alternatives","modelling","dependencies","challenging","structure","underlying","graphical","complexity","efficient","probabilistic","efficiently","conditional","discovery","facilitate","procedure","averaging","individual","independence","constraint","dimensional","understand","posterior","iterative","expectations","transformations","generating","composing","decomposing","procedures","resulting","generation","programming","densities","sequential","presenting","proposing","comparing","imitation","demonstrate","nonparametric","augmentation","sequentially","overfitting","construction","inductive","dynamical","evaluating","artificial","conventional","probability","associative","architecture","computational","initialization","proportional","architectures","solutions","computing","filtering","identified","supercomputer","describes","implemented","factorization","collaborative","multicore","preliminary","prediction","regularization","classifiers","interpreting","naturally","investigating","similarity","prototype","competitor","leveraging","interpretability","prototypes","utilizing","sensitivity"],"y":[42,41,10,34,41,219,185,12,20,108,522,119,110,732,8,42,231,49,689,52,104,90,900,47,882,174,39,340,587,30,19,232,111,62,90,84,100,33,40,26,217,107,5,316,612,57,121,9,126,85,26,0,57,61,94,87,518,28,190,22,202,271,296,174,28,3,7,59,32,38,75,50,15,184,109,43,39,82,129,76,62,42,39,5,46,4,29,2,11,136,2,403,47,14,60,77,24,38,3,121,19,17,2,17,2,187,41,30,91,6,12,84,4,262,20,31,1,82,18,24,51,46,263,321,125,47,236,456,173,183,95,52,34,108,7,120,32,94,194,71,30,75,8,44,98,3,6,44,151,136,139,7,80,14,28,76,8,585,23,33,19,26,67,22,22,64,136,98,164,11,246,267,22,16,115,148,148,65,35,4,76,104,33,36,4,35,221,76,119,8,61,14,145,28,0,51,17,5,37,33],"type":"bar"},{"x":["hierarchy","complementary"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4593,), (4593, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.815

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>the</span> <span style=''>Role</span> <span style=''>of</span> <span style=''>Canonicity</span> <span style=''>in</span> <span style=''>Bottom</span> <span style=''>up</span> <span style='background-color:rgba(0, 255, 0, 0.3632653061224489);'>Knowledge</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Compilation</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>bottom</span> <span style=''>up</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>compilation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3632653061224489);'>knowledge</span> <span style=''>bases</span> <span style=''>which</span> <span style=''>is</span> <span style=''>usually</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predicated</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>existence</span> <span style=''>of</span> <span style=''>a</span> <span style=''>polytime</span> <span style=''>function</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.32894736842105277);'>combining</span> <span style=''>compilations</span> <span style=''>using</span> <span style=''>Boolean</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>operators</span> <span style=''>(usually</span> <span style=''>called</span> <span style=''>an</span> <span style=''>Apply</span> <span style=''>function)</span> <span style=''>While</span> <span style=''>such</span> <span style=''>a</span> <span style=''>polytime</span> <span style=''>Apply</span> <span style=''>function</span> <span style=''>is</span> <span style=''>known</span> <span style=''>to</span> <span style=''>exist</span> <span style=''>for</span> <span style=''>certain</span> <span style='background-color:rgba(0, 255, 0, 0.8600000000000001);'>languages</span> <span style=''>(eg</span> <span style=''>OBDDs)</span> <span style=''>and</span> <span style=''>not</span> <span style=''>exist</span> <span style=''>for</span> <span style=''>others</span> <span style=''>(eg</span> <span style=''>DNNF)</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>existence</span> <span style=''>for</span> <span style=''>certain</span> <span style='background-color:rgba(0, 255, 0, 0.8600000000000001);'>languages</span> <span style=''>remains</span> <span style=''>unknown</span> <span style=''>Among</span> <span style=''>the</span> <span style=''>latter</span> <span style=''>is</span> <span style=''>the</span> <span style=''>recently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>language</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Sentential</span> <span style=''>Decision</span> <span style=''>Diagrams</span> <span style=''>(SDDs)</span> <span style=''>for</span> <span style=''>which</span> <span style=''>a</span> <span style=''>polytime</span> <span style=''>Apply</span> <span style=''>function</span> <span style=''>exists</span> <span style=''>for</span> <span style=''>unreduced</span> <span style=''>SDDs</span> <span style=''>but</span> <span style=''>remains</span> <span style=''>unknown</span> <span style=''>for</span> <span style=''>reduced</span> <span style=''>ones</span> <span style=''>(ie</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>canonical</span> <span style=''>SDDs)</span> <span style=''>We</span> <span style=''>resolve</span> <span style=''>this</span> <span style=''>open</span> <span style=''>question</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>and</span> <span style=''>consider</span> <span style=''>some</span> <span style=''>of</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3318284424379232);'>th ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Structured</span> <span style=''>Sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Principal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Component</span> <span style=''>Analysis</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extension</span> <span style=''>of</span> <span style=''>sparse</span> <span style=''>PCA</span> <span style=''>or</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>learning</span> <span style=''>where</span> <span style=''>the</span> <span style=''>sparsity</span> <span style=''>patterns</span> <span style=''>of</span> <span style=''>all</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>elements</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style=''>to</span> <span style=''>belong</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prespecified</span> <span style=''>set</span> <span style=''>of</span> <span style=''>shapes</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>emphstructured</span> <span style=''>sparse</span> <span style=''>PCA</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>recently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>by</span> <span style=''>1</span> <span style=''>While</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classical</span> <span style=''>sparse</span> <span style=''>priors</span> <span style=''>only</span> <span style=''>deal</span> <span style=''>with</span> <span style=''>textitcardinality</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>we</span> <span style=''>use</span> <span style=''>encodes</span> <span style=''>higher</span> <span style=''>order</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>about</span> <span style=''>the</span> <span style=''>data</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>and</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>this</span> <span style=''>problem</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Experiments</span> <span style=''>with</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style=''>tasks</span> <span style=''>face</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>and</span> <span style=''>the</span> <span style=''>study</span> <span style=''>of</span> <span style=''>the</span> <span style=''>dynamics</span> <span style=''>of</span> <span style=''>a</span> <span style=''>protein</span> <span style=''>complex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style=''>benefits</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style=''>approach</span> <span style=''>over</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Beliefs</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Probability</span> <span style=''>in</span> <span style=''>Bacchus</span> <span style=''>lp</span> <span style=''>Logic</span> <span style=''>A3</span> <span style=''>Valued</span> <span style=''>Logic</span> <span style=''>Solution</span> <span style=''>to</span> <span style=''>Apparent</span> <span style=''>Counter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intuition</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Fundamental</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discrepancy</span> <span style=''>between</span> <span style=''>first</span> <span style=''>order</span> <span style=''>logic</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3303571428571429);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>(global</span> <span style=''>versus</span> <span style=''>local</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>universe)</span> <span style=''>is</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>be</span> <span style=''>the</span> <span style=''>obstacle</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>integration</span> <span style=''>of</span> <span style=''>logic</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>in</span> <span style=''>Lp</span> <span style=''>logic</span> <span style=''>of</span> <span style=''>Bacchus</span> <span style=''>To</span> <span style=''>overcome</span> <span style=''>the</span> <span style=''>counterintuitiveness</span> <span style=''>of</span> <span style=''>Lp</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>behaviour</span> <span style=''>a</span> <span style=''>3</span> <span style=''>valued</span> <span style=''>logic</span> <span style=''>is</span> <span style=''>proposed</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Automatic</span> <span style=''>Sleep</span> <span style=''>Stage</span> <span style=''>Scoring</span> <span style=''>with</span> <span style=''>Single</span> <span style=''>Channel</span> <span style=''>EEG</span> <span style=''>Using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Convolutional</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>We</span> <span style=''>used</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>(CNNs)</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatic</span> <span style=''>sleep</span> <span style=''>stage</span> <span style=''>scoring</span> <span style=''>based</span> <span style=''>on</span> <span style=''>single</span> <span style=''>channel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>electroencephalography</span> <span style=''>(EEG)</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>task</span> <span style=''>specific</span> <span style=''>filters</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>without</span> <span style=''>using</span> <span style=''>prior</span> <span style=''>domain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>We</span> <span style=''>used</span> <span style=''>an</span> <span style=''>openly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>dataset</span> <span style=''>from</span> <span style=''>20</span> <span style=''>healthy</span> <span style=''>young</span> <span style=''>adults</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style=''>and</span> <span style=''>applied</span> <span style=''>20</span> <span style=''>fold</span> <span style=''>cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validation</span> <span style=''>We</span> <span style=''>used</span> <span style=''>class</span> <span style=''>balanced</span> <span style=''>random</span> <span style=''>sampling</span> <span style=''>within</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>(SGD)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>of</span> <span style=''>the</span> <span style=''>CNN</span> <span style=''>to</span> <span style=''>avoid</span> <span style=''>skewed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>in</span> <span style=''>favor</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represented</span> <span style=''>sleep</span> <span style=''>stages</span> <span style=''>We</span> <span style=''>achieved</span> <span style=''>high</span> <span style=''>mean</span> <span style=''>F1</span> <span style=''>score</span> <span style=''>(81</span> <span style=''>range</span> <span style=''>79</span> <span style=''>83)</span> <span style=''>mean</span> <span style=''>accuracy</span> <span style=''>across</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style=''>sleep</span> <span style=''>stages</span> <span style=''>(82</span> <span style=''>range</span> <span style=''>80</span> <span style=''>84)</span> <span style=''>and</span> <span style=''>overall</span> <span style=''>accuracy</span> <span style=''>(74</span> <span style=''>range</span> <span style=''>71</span> <span style=''>76)</span> <span style=''>over</span> <span style=''>all</span> <span style=''>subjects</span> <span style=''>By</span> <span style='background-c ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.07242739333094299)
# 	information (0.2470419505198996)
# 	architecture (0.08820365722481176)
# 	segmentation (0.07063463607027609)
# 	experimental (0.1333811401936178)
# 	representation (0.1387594119756185)
# 	different (0.262459662961635)
# 	detection (0.1197561850125493)
# 	recognition (0.12334169953388312)
# 	convolutional (0.12979562567228398)
#
# Some Statistics words are:
# 	algorithm (0.39532570860268523)
# 	estimation (0.15464942814520138)
# 	stochastic (0.14321233217304824)
# 	theoretical (0.14669318746892093)
# 	statistical (0.14818498259572352)
# 	variables (0.14917951268025859)
# 	distribution (0.1879661859771258)
# 	dimensional (0.18547986076578815)
# 	inference (0.19940328194927898)
# 	regression (0.1670810542018896)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="567967d8-bd35-4168-bb53-faeabb17b61b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("567967d8-bd35-4168-bb53-faeabb17b61b")) {                    Plotly.newPlot(                        "567967d8-bd35-4168-bb53-faeabb17b61b",                        [{"x":["hierarchy","complementary","remarkably","objectives","consequently","benchmark","furthermore","perturbation","dictionaries","reconstruction","classification","extracted","adversarial","different","regularize","parametric","parameters","increases","information","validation","hierarchical","characteristics","performance","dictionary","algorithm","objective","synthesis","optimization","algorithms","multivariate","intractable","inference","approximation","minimization","numerical","alternative","typically","integrating","integration","maximization","distribution","approximate","truncated","introduce","experiments","variational","literature","uncertainties","distributions","providing","interpret","hypernetworks","predictive","likelihood","comparable","uncertainty","framework","interpretable","estimation","primarily","automatic","outperforms","significantly","automatically","subjective","personalize","discovers","estimating","individuals","expressions","dependent","expression","personalized","traditional","regression","interpretation","measurement","correlation","considered","estimates","additionally","confidence","technical","overlooked","engineering","transparency","implications","legislation","philosophy","implementation","accountability","approaches","autonomous","intersection","requirements","addresses","deployment","possibility","deliberately","challenges","specification","precisely","philosophers","conceptual","unethical","attention","verification","regarding","particularly","engineers","problematic","distributed","mapreduce","evaluation","favorably","dynamically","subsample","appropriate","ensembles","alternatives","modelling","dependencies","challenging","structure","underlying","graphical","complexity","efficient","probabilistic","efficiently","conditional","discovery","facilitate","procedure","averaging","individual","independence","constraint","dimensional","understand","posterior","iterative","expectations","transformations","generating","composing","decomposing","procedures","resulting","generation","programming","densities","sequential","presenting","proposing","comparing","imitation","demonstrate","nonparametric","augmentation","sequentially","overfitting","construction","inductive","dynamical","evaluating","artificial","conventional","probability","associative","architecture","computational","initialization","proportional","architectures","solutions","computing","filtering","identified","supercomputer","describes","implemented","factorization","collaborative","multicore","preliminary","prediction","regularization","classifiers","interpreting","naturally","investigating","similarity","prototype","competitor","leveraging","interpretability","prototypes","utilizing","sensitivity","demonstrating","convergence","deviation","arguments","establish","straightforward","generalization","statistical","statistic","stochastic","computable","applications","martingale","empirical","concentrates","representations","according","differently","baselines","motivates","representation","importance","contributes","multimodal","modalities","demonstrated","outperform","extensive","association","supervision","independent","calibrated","likelihoods","recognition","calibration","properties","alignments","improvement","principle","posteriors","logarithm","sensitive","analyzing","implicitly","upsampled","multitude","convolution","encourages","technique","irregularity","upsampling","exp ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	hypernetworks
# 	competitor
# 	interventional
# 	discontinuous
# 	parallelize
# 	tibshirani
# 	quadrature
# 	minimised
# 	actigraphy
# 	cigarette
# 	respiration
# 	cooccurence
# 	archetypes
# 	archetypal
# 	distributive
# 	applicative
# 	unmeasured
# 	statisticians
# 	semiparametric
# 	tractography
# Some words which never appear in Statistics papers:
# 	personalize
# 	overlooked
# 	legislation
# 	accountability
# 	deliberately
# 	philosophers
# 	unethical
# 	supercomputer
# 	upsampled
# 	irregularity
# 	upsampling
# 	cyclicity
# 	hypertree
# 	predicates
# 	suspicious
# 	benchmarked
# 	algorithmically
# 	instantaneously
# 	readability
# 	understandability

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0785333866945786e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7741666666666667
